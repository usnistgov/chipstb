# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

####Preprocessing####
# Load the input file and remove "|" characters
file_path = 'dos_total.dat'

# Data storage
x_values = []
y_values = []

# Function to check if a line starts with a valid number
def starts_with_number(token):
    try:
        float(token)
        return True
    except ValueError:
        return False

# Load unique x and y values
with open(file_path, 'r') as file:
    for line in file:
        tokens = line.split()
        if tokens and starts_with_number(tokens[0]):  # Check if the first token is a valid number
            x = float(tokens[0])
            x_values.append(x)

# Load all y values
with open(file_path, 'r') as file:
    for line in file:
        tokens = line.split()
        if tokens and starts_with_number(tokens[0]):  # Check if the first token is a valid number
            y = float(tokens[1])
            y_values.append(y)

# Convert x and y values to numpy arrays
npx = np.array(x_values)+2.8734
npy = np.array(y_values)

# Check if reshaping is possible
num_bands = len(y_values) // len(x_values)
if len(y_values) % len(x_values) != 0:
    raise ValueError("Mismatch between the number of y-values and x-values. Check your data.")

# Reshape y-values into a 2D array: rows = x_values, columns = bands
ref_npy = npy.reshape(num_bands, len(x_values))

# Plotting
#plt.figure(figsize=(10, 6))
plt.clf()
for i in range(ref_npy.shape[0]):  # Iterate over rows (bands)
    plt.plot(npx, ref_npy[i, :], color='k')
plt.xlabel('Energy(E-Ef)')
plt.ylabel('DOS(arb. unit)')
plt.xlim(-8,8)
plt.legend()
plt.rcParams.update({'font.size': 22})
#plt.show()
plt.savefig('tb3py_dos.png',bbox_inches='tight')
# Out:
# /var/folders/4h/x0ppqvf13bl263984m6vck7h002fvn/T/ipykernel_13750/1073967678.py:57: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
